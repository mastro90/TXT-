# %%
# Utilities


import pandas as pd

from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, KFold, RandomizedSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer, CountVectorizer


from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC

from sklearn.feature_selection import SelectKBest, chi2

# %%
df = pd.read_csv("CleanDataset.csv")
df.head()
# Out:
#    Toxicity                                              tweet  \
# 0         0  @user when a father is dysfunctional and is so...
# 1         0  @user @user thanks for #lyft credit i can't us...
# 2         0                                bihday your majesty
# 3         0             factsguide: society now    #motivation
# 4         0  [2/2] huge fan fare and big talking before the...
#
#                                          tweet_clean  \
# 0  father dysfunctional selfish drags kids dysfun...
# 1  thanks lyft credit  can not use cause  do not ...
# 2                                     bihday majesty
# 3                      factsguide society motivation
# 4  huge fan fare big talking leave chaos pay disp...
#
#                                      tweet_tokenized  \
# 0  ['father', 'dysfunctional', 'selfish', 'drags'...
# 1  ['thanks', 'lyft', 'credit', 'can', 'not', 'us...
# 2                              ['bihday', 'majesty']
# 3            ['factsguide', 'society', 'motivation']
# 4  ['huge', 'fan', 'fare', 'big', 'talking', 'lea...
#
#                                          tweet_tok=2  \
# 0  [('father', 'dysfunctional'), ('dysfunctional'...
# 1  [('thanks', 'lyft'), ('lyft', 'credit'), ('cre...
# 2                            [('bihday', 'majesty')]
# 3  [('factsguide', 'society'), ('society', 'motiv...
# 4  [('huge', 'fan'), ('fan', 'fare'), ('fare', 'b...
#
#                                     tweet_lemmatized  \
# 0  ['father', 'dysfunctional', 'selfish', 'drag',...
# 1  ['thank', 'lyft', 'credit', 'can', 'not', 'use...
# 2                              ['bihday', 'majesty']
# 3            ['factsguide', 'society', 'motivation']
# 4  ['huge', 'fan', 'fare', 'big', 'talk', 'leave'...
#
#                                    preprocessed_text
# 0  father dysfunctional selfish drag kid dysfunct...
# 1  thank lyft credit can not use cause do not off...
# 2                                    bihday majesty
# 3                     factsguide society motivation
# 4  huge fan fare big talk leave chaos pay dispute...

# %%
X = df['preprocessed_text']
y = df["Toxicity"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=1000)

# %%
vect = CountVectorizer(min_df=5,ngram_range = (1,2))  # Convert a collection of text documents to a matrix of token counts.
vect.fit(X_train)
X_train_vec = vect.fit_transform(X_train)
X_test_vec =vect.transform(X_test)

# %%
def model_evaluation(real_v, pred_v):
    print(f"Accuracy sore: {accuracy_score(real_v, pred_v)}")
    print("Classification report:")
    print(classification_report(real_v, pred_v))
    cm = confusion_matrix(real_v, pred_v)
    print (f"Confusion matrix \n {cm}")

# %%
def customRandomSearch(X_train, y_train, model, tuned_parameters):

    print("____________________________________________ START GRID SEARCH ____________________________________________")

    results = {}
    
    print("------- Score = F1_MACRO ------- \n")
        
    k_fold = KFold(n_splits=5)
    print("> Fold = " + str(k_fold) + "\n")

    clf = RandomizedSearchCV(model, tuned_parameters, error_score='raise', cv=k_fold, scoring = 'f1_macro', return_train_score=True, n_iter=200)
    clf.fit(X_train, y_train)

    print("> Best Parameter set: \n")
    best = clf.best_params_
    print(best)
        
    print("\n> Grid scores:\n")

    means = clf.cv_results_['mean_train_score']
    stds = clf.cv_results_['std_train_score']

    print("...........RESULTS FOR TRAINING.........")
    print("........................................")

   
    
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                          
    print("____________________________________________ END GRID SEARCH ____________________________________________")
        
    results['f1_macro'] = best
    
    return results

# %%
def customGridSearch(X_train, y_train, model, tuned_parameters):

    print("____________________________________________ START GRID SEARCH ____________________________________________")

    results = {}
    
    print("------- Score = F1_MACRO ------- \n")
        
    k_fold = KFold(n_splits=5)
    print("> Fold = " + str(k_fold) + "\n")
        
    clf = GridSearchCV(model, tuned_parameters, error_score='raise', cv=k_fold, scoring = 'f1_macro', return_train_score=True)
    clf.fit(X_train, y_train)

    print("> Best Parameter set: \n")
    best = clf.best_params_
    print(best)
        
    print("\n> Grid scores:\n")

    means = clf.cv_results_['mean_train_score']
    stds = clf.cv_results_['std_train_score']

    print("...........RESULTS FOR TRAINING.........")
    print("........................................")

   
    
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
                          
    print("____________________________________________ END GRID SEARCH ____________________________________________")
        
    results['f1_macro'] = best
    
    return results

# %% [markdown]
# # NAIVE BAYES

# %%
check_params = {"selbestk__k": [200, 300, 500, 800, 1000]}

clf = Pipeline([
                ("selbestk", SelectKBest(score_func = chi2)),
                ("tfidf", TfidfTransformer()),
                ("mlnb", MultinomialNB())
                ])

results = customGridSearch(X_train_vec, y_train, clf, check_params)
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = F1_MACRO -------
#
# > Fold = KFold(n_splits=5, random_state=None, shuffle=False)
#
# > Best Parameter set:
#
# {'selbestk__k': 1000}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.889 (+/-0.003) for {'selbestk__k': 200}
# 0.892 (+/-0.002) for {'selbestk__k': 300}
# 0.893 (+/-0.004) for {'selbestk__k': 500}
# 0.898 (+/-0.003) for {'selbestk__k': 800}
# 0.901 (+/-0.003) for {'selbestk__k': 1000}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
sel = SelectKBest(chi2, k=results["f1_macro"]["selbestk__k"])  
sel.fit(X_train_vec,y_train)
X_train_sel = sel.transform(X_train_vec)
X_test_sel = sel.transform(X_test_vec)

tfidf = TfidfTransformer()
tfidf.fit(X_train_sel)
X_train_vec_bestK = tfidf.transform(X_train_sel)
X_test_vec_bestK =tfidf.transform(X_test_sel)

learner = MultinomialNB()
classifier = learner.fit(X_train_vec_bestK, y_train)
predictions = classifier.predict(X_test_vec_bestK)

# %%
model_evaluation(y_test, predictions)
# Out:
# Accuracy sore: 0.8954194084201111
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90      8713
#            1       0.87      0.90      0.88      6940
#
#     accuracy                           0.90     15653
#    macro avg       0.89      0.90      0.89     15653
# weighted avg       0.90      0.90      0.90     15653
#
# Confusion matrix
#  [[7786  927]
#  [ 710 6230]]

# %% [markdown]
# Come si può notare i risultati, con la ricerca esaustiva dei migliori iperparametri, sono i medesimi

# %% [markdown]
# # LinearSVC

# %%
check_params = {"selbestk__k": [200, 300, 500, 800, 1000],
                "svc__C": [0.01, 0.1, 1, 10, 100]}

clf = Pipeline([
                ("selbestk", SelectKBest(score_func = chi2)),
                ("tfidf", TfidfTransformer()),
                ("svc", LinearSVC())
                ])


results = customGridSearch(X_train_vec, y_train, clf, check_params)
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = F1_MACRO -------
#
# > Fold = KFold(n_splits=5, random_state=None, shuffle=False)
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# > Best Parameter set:
#
# {'selbestk__k': 1000, 'svc__C': 0.1}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.913 (+/-0.002) for {'selbestk__k': 200, 'svc__C': 0.01}
# 0.920 (+/-0.003) for {'selbestk__k': 200, 'svc__C': 0.1}
# 0.920 (+/-0.003) for {'selbestk__k': 200, 'svc__C': 1}
# 0.920 (+/-0.003) for {'selbestk__k': 200, 'svc__C': 10}
# 0.920 (+/-0.003) for {'selbestk__k': 200, 'svc__C': 100}
# 0.918 (+/-0.003) for {'selbestk__k': 300, 'svc__C': 0.01}
# 0.925 (+/-0.003) for {'selbestk__k': 300, 'svc__C': 0.1}
# 0.926 (+/-0.003) for {'selbestk__k': 300, 'svc__C': 1}
# 0.926 (+/-0.003) for {'selbestk__k': 300, 'svc__C': 10}
# 0.926 (+/-0.003) for {'selbestk__k': 300, 'svc__C': 100}
# 0.919 (+/-0.002) for {'selbestk__k': 500, 'svc__C': 0.01}
# 0.929 (+/-0.002) for {'selbestk__k': 500, 'svc__C': 0.1}
# 0.930 (+/-0.002) for {'selbestk__k': 500, 'svc__C': 1}
# 0.930 (+/-0.002) for {'selbestk__k': 500, 'svc__C': 10}
# 0.930 (+/-0.002) for {'selbestk__k': 500, 'svc__C': 100}
# 0.919 (+/-0.002) for {'selbestk__k': 800, 'svc__C': 0.01}
# 0.932 (+/-0.003) for {'selbestk__k': 800, 'svc__C': 0.1}
# 0.934 (+/-0.002) for {'selbestk__k': 800, 'svc__C': 1}
# 0.935 (+/-0.002) for {'selbestk__k': 800, 'svc__C': 10}
# 0.934 (+/-0.003) for {'selbestk__k': 800, 'svc__C': 100}
# 0.919 (+/-0.002) for {'selbestk__k': 1000, 'svc__C': 0.01}
# 0.934 (+/-0.002) for {'selbestk__k': 1000, 'svc__C': 0.1}
# 0.937 (+/-0.002) for {'selbestk__k': 1000, 'svc__C': 1}
# 0.937 (+/-0.001) for {'selbestk__k': 1000, 'svc__C': 10}
# 0.937 (+/-0.001) for {'selbestk__k': 1000, 'svc__C': 100}
# ____________________________________________ END GRID SEARCH ____________________________________________
# d:\Anaconda\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
sel = SelectKBest(chi2, k=1000)  
sel.fit(X_train_vec,y_train)
X_train_sel = sel.transform(X_train_vec)
X_test_sel = sel.transform(X_test_vec)

tfidf = TfidfTransformer()
tfidf.fit(X_train_sel)
X_train_vec_bestK = tfidf.transform(X_train_sel)
X_test_vec_bestK =tfidf.transform(X_test_sel)

learner = LinearSVC(C=0.1)
classifier = learner.fit(X_train_vec_bestK, y_train)
predictions = classifier.predict(X_test_vec_bestK)

# %%
model_evaluation(y_test,predictions)
# Out:
# Accuracy sore: 0.926659426308056
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94      8713
#            1       0.95      0.88      0.91      6940
#
#     accuracy                           0.93     15653
#    macro avg       0.93      0.92      0.93     15653
# weighted avg       0.93      0.93      0.93     15653
#
# Confusion matrix
#  [[8403  310]
#  [ 838 6102]]

# %% [markdown]
# # KNN

# %%
check_params = {"selbestk__k": [200],#[200, 300, 500, 800, 1000],
           'knn__n_neighbors': [5,7,9,11],
          #'knn__n_neighbors': list(range(5,28,2)),
          #'knn__weights': ['uniform', 'distance'],
          'knn__metric': ["euclidean", "manhattan"]}

clf = Pipeline([
                ("selbestk", SelectKBest(score_func = chi2)),
                ("tfidf", TfidfTransformer()),
                ("knn", KNeighborsClassifier())
                ])

results = customRandomSearch(X_train_vec, y_train , clf, check_params)
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = F1_MACRO -------
#
# > Fold = KFold(n_splits=5, random_state=None, shuffle=False)
#
#  Start combinations
# d:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 8 is smaller than n_iter=200. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
#  Finish combinations
# > Best Parameter set:
#
# {'selbestk__k': 200, 'knn__n_neighbors': 7, 'knn__metric': 'manhattan'}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.909 (+/-0.004) for {'selbestk__k': 200, 'knn__n_neighbors': 5, 'knn__metric': 'euclidean'}
# 0.905 (+/-0.005) for {'selbestk__k': 200, 'knn__n_neighbors': 7, 'knn__metric': 'euclidean'}
# 0.902 (+/-0.004) for {'selbestk__k': 200, 'knn__n_neighbors': 9, 'knn__metric': 'euclidean'}
# 0.901 (+/-0.003) for {'selbestk__k': 200, 'knn__n_neighbors': 11, 'knn__metric': 'euclidean'}
# 0.908 (+/-0.008) for {'selbestk__k': 200, 'knn__n_neighbors': 5, 'knn__metric': 'manhattan'}
# 0.906 (+/-0.006) for {'selbestk__k': 200, 'knn__n_neighbors': 7, 'knn__metric': 'manhattan'}
# 0.904 (+/-0.006) for {'selbestk__k': 200, 'knn__n_neighbors': 9, 'knn__metric': 'manhattan'}
# 0.901 (+/-0.006) for {'selbestk__k': 200, 'knn__n_neighbors': 11, 'knn__metric': 'manhattan'}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
sel = SelectKBest(chi2, k=200)  
sel.fit(X_train_vec,y_train)
X_train_sel = sel.transform(X_train_vec)
X_test_sel = sel.transform(X_test_vec)

tfidf = TfidfTransformer()
tfidf.fit(X_train_sel)
X_train_vec_bestK = tfidf.transform(X_train_sel)
X_test_vec_bestK =tfidf.transform(X_test_sel)

learner = KNeighborsClassifier(n_neighbors=7,metric='manhattan')
classifier = learner.fit(X_train_vec_bestK, y_train)
predictions = classifier.predict(X_test_vec_bestK)

# %%
model_evaluation(y_test,predictions)
# Out:
# Accuracy sore: 0.8964415766945634
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      8713
#            1       0.93      0.82      0.88      6940
#
#     accuracy                           0.90     15653
#    macro avg       0.90      0.89      0.89     15653
# weighted avg       0.90      0.90      0.90     15653
#
# Confusion matrix
#  [[8308  405]
#  [1216 5724]]

# %% [markdown]
# Come si può notare i risultati, con la ricerca esaustiva di alcuni parametri con k fissato( perchè troppo complesso in termini di tempo), sono migliorati.

# %% [markdown]
# # DECISION TREE

# %%
check_params = {"selbestk__k": [200, 300, 500, 800, 1000],
          'dt__max_depth': [None, 2, 5, 10, 15, 20],
          'dt__min_samples_split': [2, 5, 10, 15, 20],
          'dt__min_samples_leaf': [1, 5, 10, 15, 20]}

clf = Pipeline([
                ("selbestk", SelectKBest(score_func = chi2)),
                ("tfidf", TfidfTransformer()),
                ("dt", DecisionTreeClassifier())
                ])

results = customRandomSearch(X_train_vec, y_train, clf, check_params)
# Out:
# ____________________________________________ START GRID SEARCH ____________________________________________
# ------- Score = F1_MACRO -------
#
# > Fold = KFold(n_splits=5, random_state=None, shuffle=False)
#
#  Start combinations
#  Finish combinations
# > Best Parameter set:
#
# {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
#
# > Grid scores:
#
# ...........RESULTS FOR TRAINING.........
# ........................................
# 0.911 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': 15}
# 0.866 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': 5}
# 0.919 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 5, 'dt__max_depth': 20}
# 0.934 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.918 (+/-0.001) for {'selbestk__k': 800, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 300, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.916 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.908 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.866 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.920 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 800, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.866 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 5}
# 0.866 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.927 (+/-0.003) for {'selbestk__k': 800, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.909 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.894 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.912 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 15}
# 0.917 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 20}
# 0.940 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.930 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.918 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 20}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': 5}
# 0.909 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.895 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 10}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 10, 'dt__max_depth': 10}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.925 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.909 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 2}
# 0.805 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 5, 'dt__max_depth': 2}
# 0.940 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.908 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.894 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.927 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 10, 'dt__max_depth': None}
# 0.908 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.920 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.894 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.916 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.970 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.894 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 10}
# 0.936 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.922 (+/-0.003) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.916 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 20}
# 0.894 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.923 (+/-0.003) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.940 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.908 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.916 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.928 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.894 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.916 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.918 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.910 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 15}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.866 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 5}
# 0.908 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.926 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.922 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 2}
# 0.917 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 20}
# 0.918 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 20}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.908 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.925 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.895 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 1, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': 2}
# 0.912 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 15}
# 0.894 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': 10}
# 0.908 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.909 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.805 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.926 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': 5}
# 0.909 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.894 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.908 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.930 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.896 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.918 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 5, 'dt__max_depth': 2}
# 0.866 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.896 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.894 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.894 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.917 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 15, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.866 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': 5}
# 0.894 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.929 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.946 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': 5}
# 0.926 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.921 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.894 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.866 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.916 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.910 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 15}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.920 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.932 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.922 (+/-0.003) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.931 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': None}
# 0.916 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.909 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.918 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 20}
# 0.908 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.867 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 5}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.918 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.951 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.926 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.912 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 15}
# 0.894 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.916 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.909 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 15}
# 0.928 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.895 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 10}
# 0.943 (+/-0.004) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.927 (+/-0.003) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.937 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.916 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.866 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 5}
# 0.805 (+/-0.001) for {'selbestk__k': 800, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.909 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 15}
# 0.923 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.911 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 1, 'dt__max_depth': 15}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.805 (+/-0.001) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 2}
# 0.917 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 10, 'dt__max_depth': 20}
# 0.916 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 2}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 5}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.928 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.911 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': 15}
# 0.920 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 20}
# 0.866 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 5}
# 0.909 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 5, 'dt__max_depth': 15}
# 0.910 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 5, 'dt__max_depth': 15}
# 0.908 (+/-0.001) for {'selbestk__k': 800, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.866 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 5, 'dt__max_depth': 5}
# 0.805 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.916 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 20}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': 10}
# 0.923 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': None}
# 0.894 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.894 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.954 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': None}
# 0.805 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 2}
# 0.865 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 5}
# 0.917 (+/-0.003) for {'selbestk__k': 200, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 20}
# 0.930 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 15, 'dt__max_depth': None}
# 0.894 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.908 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.908 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.805 (+/-0.001) for {'selbestk__k': 500, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 2}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 5}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# 0.894 (+/-0.002) for {'selbestk__k': 1000, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.909 (+/-0.002) for {'selbestk__k': 200, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': 15}
# 0.918 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 5, 'dt__max_depth': 20}
# 0.894 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 10, 'dt__min_samples_leaf': 20, 'dt__max_depth': 10}
# 0.805 (+/-0.001) for {'selbestk__k': 1000, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 15, 'dt__max_depth': 2}
# 0.909 (+/-0.003) for {'selbestk__k': 300, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 15}
# 0.867 (+/-0.002) for {'selbestk__k': 300, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 1, 'dt__max_depth': 5}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 5, 'dt__max_depth': 10}
# 0.933 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 10, 'dt__max_depth': None}
# 0.866 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 1, 'dt__max_depth': 5}
# 0.866 (+/-0.001) for {'selbestk__k': 200, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 1, 'dt__max_depth': 5}
# 0.918 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 10, 'dt__max_depth': 20}
# 0.908 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 20, 'dt__max_depth': 15}
# 0.895 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 10, 'dt__max_depth': 10}
# 0.865 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 20, 'dt__max_depth': 5}
# 0.917 (+/-0.002) for {'selbestk__k': 800, 'dt__min_samples_split': 15, 'dt__min_samples_leaf': 15, 'dt__max_depth': 20}
# 0.894 (+/-0.002) for {'selbestk__k': 500, 'dt__min_samples_split': 20, 'dt__min_samples_leaf': 15, 'dt__max_depth': 10}
# ____________________________________________ END GRID SEARCH ____________________________________________

# %%
sel = SelectKBest(chi2, k=500)  
sel.fit(X_train_vec,y_train)
X_train_sel = sel.transform(X_train_vec)
X_test_sel = sel.transform(X_test_vec)

tfidf = TfidfTransformer()
tfidf.fit(X_train_sel)
X_train_vec_bestK = tfidf.transform(X_train_sel)
X_test_vec_bestK =tfidf.transform(X_test_sel)

learner = DecisionTreeClassifier(max_depth=None,min_samples_split=2,min_samples_leaf=20)
classifier = learner.fit(X_train_vec_bestK, y_train)
predictions = classifier.predict(X_test_vec_bestK)

# %%
model_evaluation(y_test,predictions)
# Out:
# Accuracy sore: 0.9182265380438255
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      8713
#            1       0.94      0.87      0.90      6940
#
#     accuracy                           0.92     15653
#    macro avg       0.92      0.91      0.92     15653
# weighted avg       0.92      0.92      0.92     15653
#
# Confusion matrix
#  [[8362  351]
#  [ 929 6011]]

# %% [markdown]
# Come si può notare i risultati, con la ricerca esaustiva di alcuni parametri, sono leggermente peggiorati.
